# %% [markdown]
# # 01 — Data Preparation
#
# Load , filter to 2008–2012, build SQLite database with normalised schema.

# %%
import sys, json, sqlite3, time
import pandas as pd
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if (PROJECT_ROOT / "src").exists():
    sys.path.insert(0, str(PROJECT_ROOT))
else:
    PROJECT_ROOT = PROJECT_ROOT.parent
    sys.path.insert(0, str(PROJECT_ROOT))

from src.utils import *
from src.data_processing import build_database, build_sample_database

# %% [markdown]
# ## 1.1 Inspect Raw JSON

# %%
# Peek at first 3 records
with open(REVIEW_JSON_PATH) as f:
    for i, line in enumerate(f):
        if i >= 3:
            break
        r = json.loads(line)
        print(json.dumps(r, indent=2, ensure_ascii=False)[:600])
        print("---")
# Out:
# {
#   "ratings": {
#     "service": 5.0,
#     "cleanliness": 5.0,
#     "overall": 5.0,
#     "value": 5.0,
#     "location": 5.0,
#     "sleep_quality": 5.0,
#     "rooms": 5.0
#   },
#   "title": "“Truly is \"Jewel of the Upper Wets Side\"”",
#   "text": "Stayed in a king suite for 11 nights and yes it cots us a bit but we were happy with the standard of room, the location and the friendliness of the staff. Our room was on the 20th floor overlooking Broadway and the madhouse of the Fairway Market. Room was quite with no noise evident from the hallway or adjoining rooms. It was great to be able to open windows wh
# ---
# {
#   "ratings": {
#     "service": 5.0,
#     "cleanliness": 5.0,
#     "overall": 5.0,
#     "value": 5.0,
#     "location": 5.0,
#     "sleep_quality": 5.0,
#     "rooms": 5.0
#   },
#   "title": "“My home away from home!”",
#   "text": "On every visit to NYC, the Hotel Beacon is the place we love to stay. So conveniently located to Central Park, Lincoln Center and great local restaurants. The rooms are lovely - beds so comfortable, a great little kitchen and new wizz bang coffee maker. The staff are so accommodating and just love walking across the street to the Fairway supermarket with every imaginable goodies
# ---
# {
#   "ratings": {
#     "service": 4.0,
#     "cleanliness": 5.0,
#     "overall": 4.0,
#     "value": 4.0,
#     "location": 5.0,
#     "sleep_quality": 4.0,
#     "rooms": 4.0
#   },
#   "title": "“Great Stay”",
#   "text": "This is a great property in Midtown. We two different rooms different rooms during our stay. The first room was in the North tower, which was quite inconvenient. You have to go through the conference area to get to the north elevators. \nThe second room was the Andaz Suite. It was nicely appointed room, but the best part about it was the bathroom. From the foot soaking bowl to the bath produ
# ---

# %% [markdown]
# ## 1.2 Build the Full Database
#
# This reads  line-by-line, filters to years 2008–2012, and inserts into a normalised SQLite DB with three tables: , , .

# %%
# Build the database (this may take a few minutes for ~550K reviews)
t0 = time.time()
total = build_database()
print(f"Inserted {total:,} reviews in {time.time()-t0:.1f}s")
# Out:
# [data_processing] Reading /Users/adrian/Workshop/5126/Assignment1/review.json …
#   … 10,000 reviews inserted (10,728 lines scanned)
#   … 20,000 reviews inserted (22,185 lines scanned)
#   … 30,000 reviews inserted (32,598 lines scanned)
#   … 40,000 reviews inserted (44,540 lines scanned)
#   … 50,000 reviews inserted (55,966 lines scanned)
#   … 60,000 reviews inserted (68,136 lines scanned)
#   … 70,000 reviews inserted (80,562 lines scanned)
#   … 80,000 reviews inserted (93,199 lines scanned)
#   … 90,000 reviews inserted (107,094 lines scanned)
#   … 100,000 reviews inserted (119,268 lines scanned)
#   … 110,000 reviews inserted (131,364 lines scanned)
#   … 120,000 reviews inserted (142,586 lines scanned)
#   … 130,000 reviews inserted (153,988 lines scanned)
#   … 140,000 reviews inserted (165,670 lines scanned)
#   … 150,000 reviews inserted (177,723 lines scanned)
#   … 160,000 reviews inserted (190,385 lines scanned)
#   … 170,000 reviews inserted (202,447 lines scanned)
#   … 180,000 reviews inserted (213,425 lines scanned)
#   … 190,000 reviews inserted (225,667 lines scanned)
#   … 200,000 reviews inserted (236,829 lines scanned)
#   … 210,000 reviews inserted (248,645 lines scanned)
#   … 220,000 reviews inserted (260,145 lines scanned)
#   … 230,000 reviews inserted (270,692 lines scanned)
#   … 240,000 reviews inserted (282,940 lines scanned)
#   … 250,000 reviews inserted (294,300 lines scanned)
#   … 260,000 reviews inserted (305,799 lines scanned)
#   … 270,000 reviews inserted (317,474 lines scanned)
#   … 280,000 reviews inserted (328,198 lines scanned)
#   … 290,000 reviews inserted (340,711 lines scanned)
#   … 300,000 reviews inserted (352,058 lines scanned)
#   … 310,000 reviews inserted (363,368 lines scanned)
#   … 320,000 reviews inserted (375,444 lines scanned)
#   … 330,000 reviews inserted (386,342 lines scanned)
#   … 340,000 reviews inserted (397,478 lines scanned)
#   … 350,000 reviews inserted (409,221 lines scanned)
#   … 360,000 reviews inserted (420,663 lines scanned)
#   … 370,000 reviews inserted (431,536 lines scanned)
#   … 380,000 reviews inserted (443,754 lines scanned)
#   … 390,000 reviews inserted (455,412 lines scanned)
#   … 400,000 reviews inserted (467,870 lines scanned)
#   … 410,000 reviews inserted (479,556 lines scanned)
#   … 420,000 reviews inserted (491,383 lines scanned)
#   … 430,000 reviews inserted (502,701 lines scanned)
#   … 440,000 reviews inserted (514,042 lines scanned)
#   … 450,000 reviews inserted (525,921 lines scanned)
#   … 460,000 reviews inserted (537,177 lines scanned)
#   … 470,000 reviews inserted (548,127 lines scanned)
#   … 480,000 reviews inserted (559,452 lines scanned)
#   … 490,000 reviews inserted (571,616 lines scanned)
#   … 500,000 reviews inserted (584,482 lines scanned)
#   … 510,000 reviews inserted (596,584 lines scanned)
#   … 520,000 reviews inserted (608,157 lines scanned)
#   … 530,000 reviews inserted (620,497 lines scanned)
#   … 540,000 reviews inserted (632,638 lines scanned)
#   … 550,000 reviews inserted (643,943 lines scanned)
#   … 560,000 reviews inserted (655,269 lines scanned)
#   … 570,000 reviews inserted (666,858 lines scanned)
#   … 580,000 reviews inserted (678,023 lines scanned)
#   … 590,000 reviews inserted (689,494 lines scanned)
#   … 600,000 reviews inserted (701,416 lines scanned)
#   … 610,000 reviews inserted (712,630 lines scanned)
#   … 620,000 reviews inserted (724,382 lines scanned)
#   … 630,000 reviews inserted (736,046 lines scanned)
#   … 640,000 reviews inserted (747,241 lines scanned)
#   … 650,000 reviews inserted (759,022 lines scanned)
#   … 660,000 reviews inserted (770,825 lines scanned)
#   … 670,000 reviews inserted (781,663 lines scanned)
#   … 680,000 reviews inserted (793,566 lines scanned)
#   … 690,000 reviews inserted (805,086 lines scanned)
#   … 700,000 reviews inserted (817,092 lines scanned)
#   … 710,000 reviews inserted (828,039 lines scanned)
#   … 720,000 reviews inserted (839,670 lines scanned)
#   … 730,000 reviews inserted (851,157 lines scanned)
#   … 740,000 reviews inserted (863,102 lines scanned)
#   … 750,000 reviews inserted (874,484 lines scanned)
# [data_processing] Creating indexes …
# [data_processing] Done — 753,445 reviews in 273.1s → /Users/adrian/Workshop/5126/Assignment1/data/reviews.db
# Inserted 753,445 reviews in 273.1s

# %% [markdown]
# ## 1.3 Verify Database

# %%
conn = get_db_connection()
for table in ["hotels", "authors", "reviews"]:
    count = conn.execute(f"SELECT COUNT(*) FROM {table}").fetchone()[0]
    print(f"{table:>10s}: {count:,} rows")
conn.close()
# Out:
#     hotels: 3,888 rows
#    authors: 522,156 rows
#    reviews: 753,445 rows

# %% [markdown]
# ## 1.4 Schema Information

# %%
conn = get_db_connection()
cursor = conn.execute("SELECT sql FROM sqlite_master WHERE type='table'")
for (ddl,) in cursor:
    print(ddl)
    print()
conn.close()
# Out:
# CREATE TABLE hotels (
#     hotel_id   INTEGER PRIMARY KEY,   -- offering_id from the source data
#     num_reviews INTEGER DEFAULT 0      -- denormalized review count
# )
#
# CREATE TABLE authors (
#     author_id          TEXT PRIMARY KEY,   -- unique hash id
#     username           TEXT,
#     location           TEXT,
#     num_cities         INTEGER,
#     num_helpful_votes  INTEGER,
#     num_reviews        INTEGER,
#     num_type_reviews   INTEGER
# )
#
# CREATE TABLE reviews (
#     review_id           INTEGER PRIMARY KEY,
#     hotel_id            INTEGER NOT NULL,
#     author_id           TEXT,
#     title               TEXT,
#     text                TEXT,
#     date                TEXT,               -- original string, e.g. 'December 17, 2012'
#     date_parsed         TEXT,               -- ISO format YYYY-MM-DD
#     year                INTEGER,
#     month               INTEGER,
#     date_stayed         TEXT,
#     rating_service      REAL,
#     rating_cleanliness  REAL,
#     rating_overall      REAL,
#     rating_value        REAL,
#     rating_location     REAL,
#     rating_sleep_quality REAL,
#     rating_rooms        REAL,
#     num_helpful_votes   INTEGER DEFAULT 0,
#     via_mobile          INTEGER DEFAULT 0,  -- boolean stored as 0/1
#     FOREIGN KEY (hotel_id) REFERENCES hotels(hotel_id),
#     FOREIGN KEY (author_id) REFERENCES authors(author_id)
# )

# %% [markdown]
# ## 1.5 Data Quality Checks

# %%
conn = get_db_connection()
df = pd.read_sql_query("SELECT * FROM reviews LIMIT 50000", conn)
print("Shape:", df.shape)
print("Null counts:")
print(df.isnull().sum())
print("Year distribution:")
print(df["year"].value_counts().sort_index())
conn.close()
# Out:
# Shape: (50000, 19)
# Null counts:
# review_id                   0
# hotel_id                    0
# author_id                   0
# title                       0
# text                        0
# date                        0
# date_parsed                 0
# year                        0
# month                       0
# date_stayed              2348
# rating_service           6593
# rating_cleanliness       5026
# rating_overall              0
# rating_value             9358
# rating_location          8956
# rating_sleep_quality    50000
# rating_rooms             4749
# num_helpful_votes           0
# via_mobile                  0
# dtype: int64
# Year distribution:
# year
# 2008    50000
# Name: count, dtype: int64

# %% [markdown]
# ## 1.6 Build Sample Database for TAs

# %%
count = build_sample_database()
print(f"Sample DB created with {count:,} reviews")
# Out:
# [data_processing] Sample DB → 5,500 reviews → /Users/adrian/Workshop/5126/Assignment1/data/reviews_sample.db
# Sample DB created with 5,500 reviews

# %% [markdown]
# ## 1.7 Summary Statistics

# %%
conn = get_db_connection()
stats = pd.read_sql_query("""
    SELECT
        COUNT(*) AS total_reviews,
        COUNT(DISTINCT hotel_id) AS total_hotels,
        COUNT(DISTINCT author_id) AS total_authors,
        MIN(date_parsed) AS earliest_date,
        MAX(date_parsed) AS latest_date,
        ROUND(AVG(rating_overall), 2) AS avg_overall_rating
    FROM reviews
""", conn)
print(stats.T.to_string())
conn.close()
# Out:
#                              0
# total_reviews           753445
# total_hotels              3888
# total_authors           522157
# earliest_date       2008-01-01
# latest_date         2012-12-20
# avg_overall_rating        3.98
